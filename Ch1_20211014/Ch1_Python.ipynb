# %% [markdown]
# # 程式語言概論與資料輸出入
#
# ## 輸出
# 範例
#
# print("內容1","內容2")
#
# [print文件](https://docs.python.org/3/library/functions.html#print)
#
# 更新命令: `conda update conda`
#
# |讀寫| rrrrrrrrrrrrrrr |
# | ------------- | ------------- |
# | 讀 | O  |
# | 寫 | X |
#
# ![image-2.png](attachment:image-2.png)
#
# [![](https://www.teepr.com/wp-content/uploads/2020/11/5d9005f941962_5a12d75f002cf1588d8de6c15bc543b6.jpg)](https://www.teepr.com/1477848/cindy/%E9%AC%BC%E6%BB%85%E4%B9%8B%E5%88%83%E5%8A%87%E5%A0%B4%E7%89%88%E5%A4%A7%E5%93%A5%E6%B2%92%E6%9C%89%E8%BC%B8/)

# %%
print("你好!","Howard","Ken",end=" ")
print("你好!","Howard","Ken",end=" ")
# Out:
# 你好! Howard Ken 你好! Howard Ken

# %%
姓名="Howard"
